# %% [markdown]
# Import numpy and panda

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# import visualization libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# load the data into Dataframes

# %%
cus_History = pd.read_csv('ml_case_training_data.csv')
price_History =pd.read_csv('ml_case_training_hist_data.csv')
churn_Indicator = pd.read_csv('ml_case_training_output.csv')

# %% [markdown]
# Checking each dataframe

# %%
cus_History.head()
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3  764c75f661154dac3a6c254cd082ea7d                               NaN
# 4  bba03439a292a1e166f80264c16191cb                               NaN
#
#    campaign_disc_ele                     channel_sales  cons_12m  \
# 0                NaN  lmkebamcaaclubfxadlmueccxoimlema    309275
# 1                NaN  foosdfpfkusacimwkcsosbicdxkicaua         0
# 2                NaN                               NaN      4660
# 3                NaN  foosdfpfkusacimwkcsosbicdxkicaua       544
# 4                NaN  lmkebamcaaclubfxadlmueccxoimlema      1584
#
#    cons_gas_12m  cons_last_month  date_activ    date_end date_first_activ  \
# 0             0            10025  2012-11-07  2016-11-06              NaN
# ...

# %%
price_History.head()
# Out:
#                                  id  price_date  price_p1_var  price_p2_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01      0.151367           0.0
# 1  038af19179925da21a25619c5a24b745  2015-02-01      0.151367           0.0
# 2  038af19179925da21a25619c5a24b745  2015-03-01      0.151367           0.0
# 3  038af19179925da21a25619c5a24b745  2015-04-01      0.149626           0.0
# 4  038af19179925da21a25619c5a24b745  2015-05-01      0.149626           0.0
#
#    price_p3_var  price_p1_fix  price_p2_fix  price_p3_fix
# 0           0.0     44.266931           0.0           0.0
# 1           0.0     44.266931           0.0           0.0
# 2           0.0     44.266931           0.0           0.0
# 3           0.0     44.266931           0.0           0.0
# 4           0.0     44.266931           0.0           0.0

# %%
churn_Indicator.head()
# Out:
#                                  id  churn
# 0  48ada52261e7cf58715202705a0451c9      0
# 1  24011ae4ebbe3035111d65fa7c15bc57      1
# 2  d29c2c54acc38ff3c0614d0a653813dd      0
# 3  764c75f661154dac3a6c254cd082ea7d      0
# 4  bba03439a292a1e166f80264c16191cb      0

# %% [markdown]
# @@ for easy comparison we can merge the customer data and churn data @@

# %%
Combined_Cusdata = pd.merge(cus_History,churn_Indicator,on='id')

# %%
Combined_Cusdata
# Out:
#                                      id                      activity_new  \
# 0      48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1      24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2      d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3      764c75f661154dac3a6c254cd082ea7d                               NaN
# 4      bba03439a292a1e166f80264c16191cb                               NaN
# ...                                 ...                               ...
# 16091  18463073fb097fc0ac5d3e040f356987                               NaN
# 16092  d0a6f71671571ed83b2645d23af6de00                               NaN
# 16093  10e6828ddd62cbcf687cb74928c4c2d2                               NaN
# 16094  1cf20fd6206d7678d5bcafd28c53b4db                               NaN
# 16095  563dde550fd624d7352f3de77c0cdfcd                               NaN
#
#        campaign_disc_ele                     channel_sales  cons_12m  \
# ...

# %%
Combined_Cusdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16096 entries, 0 to 16095
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        16096 non-null  object
#  1   activity_new              6551 non-null   object
#  2   campaign_disc_ele         0 non-null      float64
#  3   channel_sales             11878 non-null  object
#  4   cons_12m                  16096 non-null  int64
#  5   cons_gas_12m              16096 non-null  int64
#  6   cons_last_month           16096 non-null  int64
#  7   date_activ                16096 non-null  object
#  8   date_end                  16094 non-null  object
#  9   date_first_activ          3508 non-null   object
#  10  date_modif_prod           15939 non-null  object
#  11  date_renewal              16056 non-null  object
#  12  forecast_base_bill_ele    3508 non-null   float64
# ...

# %%
Combined_Cusdata.head(10)
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3  764c75f661154dac3a6c254cd082ea7d                               NaN
# 4  bba03439a292a1e166f80264c16191cb                               NaN
# 5  568bb38a1afd7c0fc49c77b3789b59a3  sfisfxfcocfpcmckuekokxuseixdaoeu
# 6  149d57cf92fc41cf94415803a877cb4b                               NaN
# 7  1aa498825382410b098937d65c4ec26d                               NaN
# 8  7ab4bf4878d8f7661dfc20e9b8e18011  sscfoipxikopfskekuobeuxkxmwsuucb
# 9  01495c955be7ec5e7f3203406785aae0                               NaN
#
#    campaign_disc_ele                     channel_sales  cons_12m  \
# 0                NaN  lmkebamcaaclubfxadlmueccxoimlema    309275
# ...

# %% [markdown]
# to ensure the data types for further visualisation and analysis check the datatype of this data frame

# %%
pd.DataFrame({'Data Type':Combined_Cusdata.dtypes})
# Out:
#                          Data Type
# id                          object
# activity_new                object
# campaign_disc_ele          float64
# channel_sales               object
# cons_12m                     int64
# cons_gas_12m                 int64
# cons_last_month              int64
# date_activ                  object
# date_end                    object
# date_first_activ            object
# date_modif_prod             object
# date_renewal                object
# forecast_base_bill_ele     float64
# forecast_base_bill_year    float64
# forecast_bill_12m          float64
# forecast_cons              float64
# forecast_cons_12m          float64
# forecast_cons_year           int64
# forecast_discount_energy   float64
# forecast_meter_rent_12m    float64
# forecast_price_energy_p1   float64
# forecast_price_energy_p2   float64
# forecast_price_pow_p1      float64
# has_gas                     object
# imp_cons                   float64
# margin_gross_pow_ele       float64
# ...

# %%
churn = Combined_Cusdata[['id','churn']]

# %%
churn
# Out:
#                                      id  churn
# 0      48ada52261e7cf58715202705a0451c9      0
# 1      24011ae4ebbe3035111d65fa7c15bc57      1
# 2      d29c2c54acc38ff3c0614d0a653813dd      0
# 3      764c75f661154dac3a6c254cd082ea7d      0
# 4      bba03439a292a1e166f80264c16191cb      0
# ...                                 ...    ...
# 16091  18463073fb097fc0ac5d3e040f356987      0
# 16092  d0a6f71671571ed83b2645d23af6de00      1
# 16093  10e6828ddd62cbcf687cb74928c4c2d2      1
# 16094  1cf20fd6206d7678d5bcafd28c53b4db      0
# 16095  563dde550fd624d7352f3de77c0cdfcd      0
#
# [16096 rows x 2 columns]

# %%
churn.columns = ['companies','churn']

# %%
churn
# Out:
#                               companies  churn
# 0      48ada52261e7cf58715202705a0451c9      0
# 1      24011ae4ebbe3035111d65fa7c15bc57      1
# 2      d29c2c54acc38ff3c0614d0a653813dd      0
# 3      764c75f661154dac3a6c254cd082ea7d      0
# 4      bba03439a292a1e166f80264c16191cb      0
# ...                                 ...    ...
# 16091  18463073fb097fc0ac5d3e040f356987      0
# 16092  d0a6f71671571ed83b2645d23af6de00      1
# 16093  10e6828ddd62cbcf687cb74928c4c2d2      1
# 16094  1cf20fd6206d7678d5bcafd28c53b4db      0
# 16095  563dde550fd624d7352f3de77c0cdfcd      0
#
# [16096 rows x 2 columns]

# %%
Churn_PriceData = pd.merge(price_History,churn_Indicator,on='id')

# %%
Churn_PriceData
# Out:
#                                       id  price_date  price_p1_var  \
# 0       038af19179925da21a25619c5a24b745  2015-01-01      0.151367
# 1       038af19179925da21a25619c5a24b745  2015-02-01      0.151367
# 2       038af19179925da21a25619c5a24b745  2015-03-01      0.151367
# 3       038af19179925da21a25619c5a24b745  2015-04-01      0.149626
# 4       038af19179925da21a25619c5a24b745  2015-05-01      0.149626
# ...                                  ...         ...           ...
# 192997  16f51cdc2baa19af0b940ee1b3dd17d5  2015-08-01      0.119916
# 192998  16f51cdc2baa19af0b940ee1b3dd17d5  2015-09-01      0.119916
# 192999  16f51cdc2baa19af0b940ee1b3dd17d5  2015-10-01      0.119916
# 193000  16f51cdc2baa19af0b940ee1b3dd17d5  2015-11-01      0.119916
# 193001  16f51cdc2baa19af0b940ee1b3dd17d5  2015-12-01      0.119916
#
#         price_p2_var  price_p3_var  price_p1_fix  price_p2_fix  price_p3_fix  \
# 0           0.000000      0.000000     44.266931       0.00000      0.000000
# ...

# %%
Churn_PriceData.plot()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='churn',data=Churn_PriceData,palette='viridis')
# Out:
# <AxesSubplot:xlabel='churn', ylabel='count'>

# %% [markdown]
# ***Exploring Data

# %%
cus_History.describe(include='all')
# Out:
#                                       id                      activity_new  \
# count                              16096                              6551
# unique                             16096                               419
# top     f9b4b659ad264e54f0600865599dff78  apdekpcbwosbxepsfxclislboipuxpop
# freq                                   1                              1577
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
# ...

# %% [markdown]
# ***checking for null value

# %%
data = cus_History.copy()

# %%
data.isnull().sum()
# Out:
# id                              0
# activity_new                 9545
# campaign_disc_ele           16096
# channel_sales                4218
# cons_12m                        0
# cons_gas_12m                    0
# cons_last_month                 0
# date_activ                      0
# date_end                        2
# date_first_activ            12588
# date_modif_prod               157
# date_renewal                   40
# forecast_base_bill_ele      12588
# forecast_base_bill_year     12588
# forecast_bill_12m           12588
# forecast_cons               12588
# forecast_cons_12m               0
# forecast_cons_year              0
# forecast_discount_energy      126
# forecast_meter_rent_12m         0
# forecast_price_energy_p1      126
# forecast_price_energy_p2      126
# forecast_price_pow_p1         126
# has_gas                         0
# imp_cons                        0
# margin_gross_pow_ele           13
# margin_net_pow_ele             13
# ...

# %%
newCus_Hist = cus_History.dropna(axis=0, how="any", inplace=False)

# %%
newCus_Hist
# Out:
# Empty DataFrame
# Columns: [id, activity_new, campaign_disc_ele, channel_sales, cons_12m, cons_gas_12m, cons_last_month, date_activ, date_end, date_first_activ, date_modif_prod, date_renewal, forecast_base_bill_ele, forecast_base_bill_year, forecast_bill_12m, forecast_cons, forecast_cons_12m, forecast_cons_year, forecast_discount_energy, forecast_meter_rent_12m, forecast_price_energy_p1, forecast_price_energy_p2, forecast_price_pow_p1, has_gas, imp_cons, margin_gross_pow_ele, margin_net_pow_ele, nb_prod_act, net_margin, num_years_antig, origin_up, pow_max]
# Index: []
#
# [0 rows x 32 columns]

# %%
cus_History.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# Out:
# Empty DataFrame
# Columns: [id, activity_new, campaign_disc_ele, channel_sales, cons_12m, cons_gas_12m, cons_last_month, date_activ, date_end, date_first_activ, date_modif_prod, date_renewal, forecast_base_bill_ele, forecast_base_bill_year, forecast_bill_12m, forecast_cons, forecast_cons_12m, forecast_cons_year, forecast_discount_energy, forecast_meter_rent_12m, forecast_price_energy_p1, forecast_price_energy_p2, forecast_price_pow_p1, has_gas, imp_cons, margin_gross_pow_ele, margin_net_pow_ele, nb_prod_act, net_margin, num_years_antig, origin_up, pow_max]
# Index: []
#
# [0 rows x 32 columns]

# %%
cus_History.plot()
# Out:
# <AxesSubplot:>
