# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
df =  pd.read_csv('myStcockData.csv')

# %%
df
# Out:
#          Action                 Time          ISIN Ticker  \
# 0       Deposit  2021-01-07 10:02:59           NaN    NaN
# 1    Market buy  2021-01-07 10:07:26  DE0007472060    WDI
# 2    Market buy  2021-01-07 10:21:17  IE00B1XNHC34   INRG
# 3    Market buy  2021-01-07 10:50:55  GB0009895292    AZN
# 4    Market buy  2021-01-08 14:31:08  US88160R1014   TSLA
# ..          ...                  ...           ...    ...
# 270  Market buy  2021-04-28 19:50:24  VGG9396G1182    MYT
# 271     Deposit  2021-04-29 12:02:55           NaN    NaN
# 272  Market buy  2021-04-29 12:04:04  FR0010478248    ATA
# 273  Market buy  2021-04-29 12:23:22  GB00BNK9TP58   TRST
# 274     Deposit  2021-04-30 19:04:16           NaN    NaN
#
#                             Name  No. of shares  Price / share  \
# 0                            NaN            NaN            NaN
# 1                       Wirecard         10.000           0.94
# 2    iShares Global Clean Energy          1.000        1391.50
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Action                         275 non-null    object
#  1   Time                           275 non-null    object
#  2   ISIN                           210 non-null    object
#  3   Ticker                         210 non-null    object
#  4   Name                           210 non-null    object
#  5   No. of shares                  210 non-null    float64
#  6   Price / share                  210 non-null    float64
#  7   Currency (Price / share)       210 non-null    object
#  8   Exchange rate                  210 non-null    object
#  9   Result (EUR)                   37 non-null     float64
#  10  Total (EUR)                    275 non-null    float64
#  11  Withholding tax                5 non-null      float64
# ...

# %%
df['No. of shares'].head()
# Out:
# 0       NaN
# 1    10.000
# 2     1.000
# 3     0.130
# 4     0.011
# Name: No. of shares, dtype: float64

# %%
df['Currency conversion fee (EUR)'].sum()
# Out:
# 0.98

# %%
df['Stamp duty reserve tax (EUR)'].sum()
# Out:
# 1.8599999999999999

# %%
df['Deposit fee (EUR)'].sum()
# Out:
# 21.450000000000003

# %%
df['Withholding tax'].sum()
# Out:
# 0.09

# %%
df['Charge amount (EUR)']
# Out:
# 0       50.00
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 270       NaN
# 271    100.70
# 272       NaN
# 273       NaN
# 274     10.07
# Name: Charge amount (EUR), Length: 275, dtype: float64

# %%
df['Action'].min()
# Out:
# 'Deposit'

# %%
my_filtered_csv = pd.read_csv('myStcockData.csv', usecols=['Name', 'No. of shares', 'Price / share'])

# %%
my_filtered_csv
# Out:
#                             Name  No. of shares  Price / share
# 0                            NaN            NaN            NaN
# 1                       Wirecard         10.000           0.94
# 2    iShares Global Clean Energy          1.000        1391.50
# 3                    AstraZeneca          0.130        7466.00
# 4                          Tesla          0.011         856.31
# ..                           ...            ...            ...
# 270                   Urban Tea           8.400           2.91
# 271                          NaN            NaN            NaN
# 272                        Atari        140.000           0.66
# 273                   Trustpilot          2.400         314.00
# 274                          NaN            NaN            NaN
#
# [275 rows x 3 columns]

# %%
my_UsableData = my_filtered_csv.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
# Out:
# <AxesSubplot:>

# %%
my_UsableData
# Out:
#                             Name  No. of shares  Price / share
# 1                       Wirecard         10.000           0.94
# 2    iShares Global Clean Energy          1.000        1391.50
# 3                    AstraZeneca          0.130        7466.00
# 4                          Tesla          0.011         856.31
# 6                      Coca-Cola          0.450          50.23
# ..                           ...            ...            ...
# 267                     Alpine 4         20.000           4.97
# 268                      Savara          12.500           2.03
# 270                   Urban Tea           8.400           2.91
# 272                        Atari        140.000           0.66
# 273                   Trustpilot          2.400         314.00
#
# [210 rows x 3 columns]

# %%
my_UsableData.plot()
# Out:
# <AxesSubplot:>

# %%
my_UsableData.head(10)
# Out:
#                            Name  No. of shares  Price / share
# 1                      Wirecard         10.000           0.94
# 2   iShares Global Clean Energy          1.000        1391.50
# 3                   AstraZeneca          0.130        7466.00
# 4                         Tesla          0.011         856.31
# 6                     Coca-Cola          0.450          50.23
# 7                         Tesla          0.040         844.00
# 8                         Tesla          0.011         839.54
# 9                    Telefonica          1.000           2.28
# 12       Advanced Micro Devices          0.250          91.17
# 13    American Lithium Minerals         10.000           0.95

# %%
df2 = my_UsableData.groupby(['Name']).sum()

# %%
df2.head(20)
# Out:
#                                No. of shares  Price / share
# Name
# -3x Short Tesla GraniteShares        4600.00           0.02
# AMC Entertainment Holdings              2.40          19.06
# Advanced Micro Devices                  0.25          91.17
# Alpine 4                               88.00          18.60
# American Battery Metals                18.30           8.57
# American Lithium Minerals              30.00           1.53
# AstraZeneca                             3.37       73034.40
# Astronics                               2.00          30.90
# Atari                                 226.80           4.46
# Bantec                               1340.00           0.11
# BioLine RX                              7.50           3.40
# Biolase                               115.00           0.98
# BlackBerry                              2.80          19.87
# Castor Maritime                        66.00           1.16
# Ceragon Networks                       20.00           4.77
# ...

# %%
my_UsableData.to_excel (r'C:\Users\User\Downloads\Py-DS-ML-Bootcamp-master\stocknew.xlsx', index = None, header=True)

# %% [markdown]
# above code is to conver csv to excel and store a particular location
